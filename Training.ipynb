# %% [markdown]
# \**Downloading, Installing & Importing Required Libraries**

# %%
import os
import h5py
import math
import torch
from torch.utils.data import Dataset

# %%
# !pip install transformers
# !pip install accelerate -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\devth\appdata\roaming\python\python39\site-packages (4.39.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\devth\appdata\roaming\python\python39\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\devth\appdata\roaming\python\python39\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\devth\appdata\roaming\python\python39\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\devth\appdata\roaming\python\python39\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\devth\appdata\roaming\python\python39\site-packages (from transformers) (23.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\devth\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\devth\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: colorama in c:\users\devth\appdata\roaming\python\python39\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: accelerate in c:\users\devth\appdata\roaming\python\python39\site-packages (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: torch>=1.10.0 in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (2.2.2)
# Requirement already satisfied: psutil in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (5.9.4)
# Requirement already satisfied: huggingface-hub in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (23.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\devth\appdata\roaming\python\python39\site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2.8.4)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2.11.3)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.10.1)
# Requirement already satisfied: fsspec in c:\users\devth\appdata\roaming\python\python39\site-packages (from torch>=1.10.0->accelerate) (2024.2.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\devth\appdata\roaming\python\python39\site-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (4.64.1)
# Requirement already satisfied: colorama in c:\users\devth\appdata\roaming\python\python39\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2022.9.14)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.2.1)

# %%
from transformers import (
    AutoConfig,
    AutoModelWithLMHead,
    AutoTokenizer,
    DataCollatorForLanguageModeling,
    PreTrainedTokenizer,
    Trainer,
    TrainingArguments,
    set_seed,
    TrainerCallback
)
import accelerate
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **Mounting Google Drive for importing the Data Files which will be used in the Tokenization**

# %% [markdown]
# **Selecting the GPU to Train the Model**

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["CUDA_LAUNCH_BLOCKING"]="0"

# %% [markdown]
# **Defining the Method that will Create the Pytorch Compatible Dataset Class**

# %%
class H5Dataset(Dataset):
    def __init__(self, tokenizer, file_path="C:\Users\devth\Desktop\NLP_Project\train_temp.txt", block_size=512):
        cached_features_file = "./data_temp.h5"

        # logger.info("Loading features from cached file %s", cached_features_file)
        print(("Loading features from cached file %s", cached_features_file))
        with h5py.File(cached_features_file, 'r') as f:
            if file_path=="C:\Users\devth\Desktop\NLP_Project\test_temp.txt":
                self.samples = f[file_path][:] #this is a dev set, 30% of a test set
            else:
                self.samples = f[file_path][:]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, item):
        return torch.tensor(self.samples[item])

# %%
def get_dataset( tokenizer, evaluate=False, local_rank=-1):
  file_path = "./test_temp.txt" if evaluate else "./train_temp.txt"
  return H5Dataset(tokenizer=tokenizer, file_path=file_path)
# Out:
#   Cell In[15], line 2
#     file_path = "C:\Users\devth\Desktop\NLP_Project\test_temp.txt" if evaluate else "C:\Users\devth\Desktop\NLP_Project\train_temp.txt"
#                                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# **Performing Transformer Configuration**

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
print(torch.cuda.is_available())  # Should return True
print(torch.version.cuda)         # Should print the CUDA version
# Out:
# False
# None

# %%
config = AutoConfig.from_pretrained('gpt2', cache_dir='cache')
set_seed(20)

# %% [markdown]
# **Defining the Tokenizer for the Model Training**

# %%
tokenizer = AutoTokenizer.from_pretrained('gpt2', cache_dir= 'cache')

# %% [markdown]
# **Initialising the GPT2 Model**

# %%
model = AutoModelWithLMHead.from_pretrained('gpt2',config=config,cache_dir='cache',)
# Out:
# C:\Users\devth\AppData\Roaming\Python\Python39\site-packages\transformers\models\auto\modeling_auto.py:1682: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(

# %% [markdown]
# **Adding the Special Recipe Token to the Tokenizer**

# %%
special_tokens = {
    "additional_special_tokens": [
        '<RECIPE_START>',
        '<INPUT_START>',
        '<NEXT_INPUT>',
        '<INPUT_END>',
        '<INGR_START>',
        '<NEXT_INGR>',
        '<INGR_END>',
        '<INSTR_START>',
        '<NEXT_INSTR>',
        '<INSTR_END>',
        '<TITLE_START>',
        '<TITLE_END>',
        '<RECIPE_END>'
    ]
}

# %% [markdown]
# **Resizeing the Model to Fit the Tokenizer with Special Tokens**

# %%
tokenizer.add_special_tokens(special_tokens)
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(50270, 768)

# %% [markdown]
# **Converting the Train and Validation Dataset to Pytorch Dataset so as it can be given to the Model as Input for Training**

# %%
train_dataset = (get_dataset(tokenizer=tokenizer))
eval_dataset = (get_dataset(tokenizer=tokenizer, evaluate=True))
# Out:
# ('Loading features from cached file %s', './data_temp.h5')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train_dataset = (get_dataset(tokenizer=tokenizer))
#       2 eval_dataset = (get_dataset(tokenizer=tokenizer, evaluate=True))
#
# Cell In[6], line 3, in get_dataset(tokenizer, evaluate, local_rank)
#       1 def get_dataset( tokenizer, evaluate=False, local_rank=-1):
#       2   file_path = "./test_temp.txt" if evaluate else "./train_temp.txt"
# ----> 3   return H5Dataset(tokenizer=tokenizer, file_path=file_path)
#
# Cell In[5], line 11, in H5Dataset.__init__(self, tokenizer, file_path, block_size)
#       9     self.samples = f[file_path][:] #this is a dev set, 30% of a test set
#      10 else:
# ---> 11     self.samples = f[file_path][:]
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\h5py\_hl\group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5o.pyx:241, in h5py.h5o.open()
#
# KeyError: "Unable to synchronously open object (object 'train_temp.txt' doesn't exist)"

# %% [markdown]
# **To be able to build batches, data collators may apply some processing (like padding).Some of them (like DataCollatorForLanguageModeling) also apply some random data augmentation (like random masking) oin the formed batch.
# Data collators are objects that will form a batch by using a list of dataset elements as input. These elements are of the same type as the elements of train_dataset or eval_dataset.Forming the batches to dataset to be trained
# source :- Hugginface.co**

# %%
data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer, mlm=False, mlm_probability=0.15  )
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
training_args = TrainingArguments(
    output_dir="./project_model",
    logging_dir="./logs",  # Directory for the logs
    num_train_epochs=2,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=8,
    evaluation_strategy="steps",
    eval_steps=500,  # Add this to perform evaluation every 500 steps
    save_strategy="steps",
    save_steps=500,  # Checkpoints will be saved every 500 steps
    logging_steps=10,  # Log training information every 10 steps
    fp16=True,
    fp16_opt_level='O1',
    warmup_steps=100,
    learning_rate=5e-4,
    adam_epsilon=1e-8,
    weight_decay=0.01,
    save_total_limit=3,  # Keep only the 3 most recent checkpoints
    metric_for_best_model="loss",  # Assumes you want to use loss to determine the best model
    greater_is_better=False,  # Lower loss indicates a better model
    report_to="tensorboard",  # Enable logging to TensorBoard
)
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **Initializing PyTorch Trainer**

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **Saving the Tokenizer Object & Starting Training and Saving the model after Finishing the training**

# %%
tokenizer.save_pretrained('./project_model')
trainer.train()
trainer.save_model()
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **Saving the Tokenizer**

# %%
tokenizer.save_pretrained('./project_model')
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import os

model_directory = './project_model'

for filename in os.listdir(model_directory):
    file_path = os.path.join(model_directory, filename)
    
    print(f"File available at: {file_path}")
# Out:
# Running cells with 'Python 3.10.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/devth/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'
